# %% [markdown]
# # Printing dataset details

# %%
import pandas as pd
import math

df = pd.read_csv('dev_train_marco.csv')
total_number_questions=len(df)
print (total_number_questions)


tot_number_of_paragraphs_for_all_question=0
tot_num_of_words_in_all_para_for_all_questions=0
num_para_for_this_ques=12
num_of_words_in_all_para_for_a_question=645
tot_passages_selected_for_a_question=1
tot_passages_selected_for_a_question_list=[]

for x in xrange(total_number_questions):
    if x%1000==0:
        print (x)
    
    tot_number_of_paragraphs_for_all_question=tot_number_of_paragraphs_for_all_question+num_para_for_this_ques
    tot_num_of_words_in_all_para_for_all_questions=tot_num_of_words_in_all_para_for_all_questions+num_of_words_in_all_para_for_a_question
    tot_passages_selected_for_a_question_list.append(tot_passages_selected_for_a_question)
    
    num_para_for_this_ques=0
    num_of_words_in_all_para_for_a_question=0
    tot_passages_selected_for_a_question=0
    

    if math.isnan(df.iloc[x].data_passages_0_is_selected):
        num_para_for_this_ques=0
        num_of_words_in_all_para_for_a_question=0
        continue
    
    elif math.isnan(df.iloc[x].data_passages_1_is_selected):
        num_para_for_this_ques=1
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_2_is_selected):
        num_para_for_this_ques=2
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected        
        continue
    
    elif math.isnan(df.iloc[x].data_passages_3_is_selected):
        num_para_for_this_ques=3
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_4_is_selected):
        num_para_for_this_ques=4
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_5_is_selected):
        num_para_for_this_ques=5
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_6_is_selected):
        num_para_for_this_ques=6
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_7_is_selected):
        num_para_for_this_ques=7
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())+len(df.iloc[x].data_passages_6_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected+df.iloc[x].data_passages_6_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_8_is_selected):
        num_para_for_this_ques=8
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())+len(df.iloc[x].data_passages_6_passage_text.split())+len(df.iloc[x].data_passages_7_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected+df.iloc[x].data_passages_6_is_selected+df.iloc[x].data_passages_7_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_9_is_selected):
        num_para_for_this_ques=9
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())+len(df.iloc[x].data_passages_6_passage_text.split())+len(df.iloc[x].data_passages_7_passage_text.split())+len(df.iloc[x].data_passages_8_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected+df.iloc[x].data_passages_6_is_selected+df.iloc[x].data_passages_7_is_selected+df.iloc[x].data_passages_8_is_selected
        continue
        
    elif math.isnan(df.iloc[x].data_passages_10_is_selected):
        num_para_for_this_ques=10
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())+len(df.iloc[x].data_passages_6_passage_text.split())+len(df.iloc[x].data_passages_7_passage_text.split())+len(df.iloc[x].data_passages_8_passage_text.split())+len(df.iloc[x].data_passages_9_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected+df.iloc[x].data_passages_6_is_selected+df.iloc[x].data_passages_7_is_selected+df.iloc[x].data_passages_8_is_selected+df.iloc[x].data_passages_9_is_selected
        continue       
        
    elif math.isnan(df.iloc[x].data_passages_11_is_selected):
        num_para_for_this_ques=11
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())+len(df.iloc[x].data_passages_6_passage_text.split())+len(df.iloc[x].data_passages_7_passage_text.split())+len(df.iloc[x].data_passages_8_passage_text.split())+len(df.iloc[x].data_passages_9_passage_text.split())+len(df.iloc[x].data_passages_10_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected+df.iloc[x].data_passages_6_is_selected+df.iloc[x].data_passages_7_is_selected+df.iloc[x].data_passages_8_is_selected+df.iloc[x].data_passages_9_is_selected+df.iloc[x].data_passages_10_is_selected
        continue               
        
    else:
        num_para_for_this_ques=12 
        num_of_words_in_all_para_for_a_question=len(df.iloc[x].data_passages_0_passage_text.split())+len(df.iloc[x].data_passages_1_passage_text.split())+len(df.iloc[x].data_passages_2_passage_text.split())+len(df.iloc[x].data_passages_3_passage_text.split())+len(df.iloc[x].data_passages_4_passage_text.split())+len(df.iloc[x].data_passages_5_passage_text.split())+len(df.iloc[x].data_passages_6_passage_text.split())+len(df.iloc[x].data_passages_7_passage_text.split())+len(df.iloc[x].data_passages_8_passage_text.split())+len(df.iloc[x].data_passages_9_passage_text.split())+len(df.iloc[x].data_passages_10_passage_text.split())+len(df.iloc[x].data_passages_11_passage_text.split())
        tot_passages_selected_for_a_question=df.iloc[x].data_passages_0_is_selected+df.iloc[x].data_passages_1_is_selected+df.iloc[x].data_passages_2_is_selected+df.iloc[x].data_passages_3_is_selected+df.iloc[x].data_passages_4_is_selected+df.iloc[x].data_passages_5_is_selected+df.iloc[x].data_passages_6_is_selected+df.iloc[x].data_passages_7_is_selected+df.iloc[x].data_passages_8_is_selected+df.iloc[x].data_passages_9_is_selected+df.iloc[x].data_passages_10_is_selected+df.iloc[x].data_passages_11_is_selected
        continue
        
        
print (tot_num_of_words_in_all_para_for_all_questions)
print (tot_number_of_paragraphs_for_all_question)
avg_number_of_paragraphs_per_question=tot_number_of_paragraphs_for_all_question/total_number_questions
print (avg_number_of_paragraphs_per_question)
avg_number_of_words_per_paragraph=tot_num_of_words_in_all_para_for_all_questions/tot_number_of_paragraphs_for_all_question
print (avg_number_of_words_per_paragraph)
avg_doc_length_for_a_question=tot_num_of_words_in_all_para_for_all_questions/total_number_questions
print (avg_doc_length_for_a_question)

print (len(tot_passages_selected_for_a_question_list))

for kl in xrange(len(tot_passages_selected_for_a_question_list)):
    tot_passages_selected_for_a_question_list[kl]=int(tot_passages_selected_for_a_question_list[kl])

number_of_questions_with_0_paragraphs=tot_passages_selected_for_a_question_list.count(0)
number_of_questions_with_1_paragraphs=tot_passages_selected_for_a_question_list.count(1)
number_of_questions_with_2_paragraphs=tot_passages_selected_for_a_question_list.count(2)
number_of_questions_with_3_paragraphs=tot_passages_selected_for_a_question_list.count(3)
number_of_questions_with_4_paragraphs=tot_passages_selected_for_a_question_list.count(4)
number_of_questions_with_5_paragraphs=tot_passages_selected_for_a_question_list.count(5)
number_of_questions_with_6_paragraphs=tot_passages_selected_for_a_question_list.count(6)
number_of_questions_with_7_paragraphs=tot_passages_selected_for_a_question_list.count(7)


print (number_of_questions_with_0_paragraphs)
print (number_of_questions_with_1_paragraphs)
print (number_of_questions_with_2_paragraphs)
print (number_of_questions_with_3_paragraphs)
print (number_of_questions_with_4_paragraphs)
print (number_of_questions_with_5_paragraphs)
print (number_of_questions_with_6_paragraphs)
print (number_of_questions_with_7_paragraphs)

print (number_of_questions_with_0_paragraphs+number_of_questions_with_1_paragraphs+number_of_questions_with_2_paragraphs+number_of_questions_with_3_paragraphs+number_of_questions_with_4_paragraphs+number_of_questions_with_5_paragraphs+number_of_questions_with_6_paragraphs+number_of_questions_with_7_paragraphs)

# %% [markdown]
# # Creating Dataset 1
# - Eliminating questions with no paragraphs
# - Eliminating questions with no answers
# - Considering only the paragraphs marked as 1 (deleting paragraphs marked as 0)

# %%
import pandas as pd
import numpy as np 
new_list=[]
l=tot_passages_selected_for_a_question_list


## If any question has zero paragraphs, don't consider it 
for ind in xrange(len(l)):
    if l[ind]!=0:
        #print ind, l[ind]
        new_list.append(ind)   
        
for inde in xrange(len(new_list)):
    new_list[inde]-=1

# Exclude indices with no answers given     
real_list=[]   
for indic in new_list:
    if isinstance(df.iloc[indic].data_answers_0, str):
        real_list.append(indic)
           
print len(real_list)
        
    
counter=0
master_list=[]


for i in real_list:
    counter+=1
    if counter%1000==0:
        print counter
    
    
    tot_passages_selected_for_this_question=0
    tot_answers_selected_for_this_question=0
    
    present_query_list=[]
    present_query_list.append(df.iloc[i].data_query)
    #present_query_list.append(df.iloc[i].data_query_codemixed)
    present_query_list.append(df.iloc[i].data_query_id)
    present_query_list.append(df.iloc[i].data_query_type)
 
    x=i
        
    if isinstance(df.iloc[i].data_answers_0, str):
        tot_answers_selected_for_this_question=1
        
    if isinstance(df.iloc[i].data_answers_1, str):
        tot_answers_selected_for_this_question=2
        
    if isinstance(df.iloc[i].data_answers_2, str):
        tot_answers_selected_for_this_question=3

    if isinstance(df.iloc[i].data_answers_3, str):
        tot_answers_selected_for_this_question=4
          
    present_query_list.append(df.iloc[i].data_answers_0)
    present_query_list.append(df.iloc[i].data_answers_1)
    present_query_list.append(df.iloc[i].data_answers_2)
    present_query_list.append(df.iloc[i].data_answers_3)

 
    if not math.isnan(df.iloc[i].data_passages_0_is_selected):
        if int(df.iloc[i].data_passages_0_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_0_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_0_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
    if not math.isnan(df.iloc[i].data_passages_1_is_selected):
        if int(df.iloc[i].data_passages_1_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_1_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_1_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
  
    if not math.isnan(df.iloc[i].data_passages_2_is_selected):
        if int(df.iloc[i].data_passages_2_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_2_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_2_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
    
    if not math.isnan(df.iloc[i].data_passages_3_is_selected):
        if int(df.iloc[i].data_passages_3_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_3_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_3_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
        
    if not math.isnan(df.iloc[i].data_passages_4_is_selected):
        if int(df.iloc[i].data_passages_4_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_4_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_4_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
    if not math.isnan(df.iloc[i].data_passages_5_is_selected):
        if int(df.iloc[i].data_passages_5_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_5_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_5_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
    if not math.isnan(df.iloc[i].data_passages_6_is_selected):
        if int(df.iloc[i].data_passages_6_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_6_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_6_is_selected
        else: 
            present_query_list.append(np.nan)
            
    else: 
        present_query_list.append(np.nan)
            
            
    if not math.isnan(df.iloc[i].data_passages_7_is_selected):
        if int(df.iloc[i].data_passages_7_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_7_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_7_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
    if not math.isnan(df.iloc[i].data_passages_8_is_selected):
        if int(df.iloc[i].data_passages_8_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_8_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_8_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            
            
        
    if not math.isnan(df.iloc[i].data_passages_9_is_selected):
        if int(df.iloc[i].data_passages_9_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_9_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_9_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
        
    if not math.isnan(df.iloc[i].data_passages_10_is_selected):
        if int(df.iloc[i].data_passages_10_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_10_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_10_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
        
    if not math.isnan(df.iloc[i].data_passages_11_is_selected):
        if int(df.iloc[i].data_passages_11_is_selected)==1:
            present_query_list.append(df.iloc[i].data_passages_11_passage_text)
            tot_passages_selected_for_this_question+=df.iloc[i].data_passages_11_is_selected
        else: 
            present_query_list.append(np.nan)
    else: 
        present_query_list.append(np.nan)
            

    present_query_list.append(int(tot_passages_selected_for_this_question))
    present_query_list.append(int(tot_answers_selected_for_this_question))
    
    master_list.append(present_query_list)

print len(master_list)
    
df_final = pd.DataFrame(master_list)
#df_final.columns = ['data_query', 'data_query_codemixed', 'data_query_id', 'data_query_type','data_answers_0', 'data_answers_1', 'data_answers_2', 'data_answers_3', 'data_passages_0_passage_text','data_passages_1_passage_text', 'data_passages_2_passage_text', 'data_passages_3_passage_text','data_passages_4_passage_text','data_passages_5_passage_text', 'data_passages_6_passage_text', 'data_passages_7_passage_text', 'data_passages_8_passage_text', 'data_passages_9_passage_text','data_passages_10_passage_text','data_passages_11_passage_text','num_passages','num_answers' ]
df_final.columns = ['data_query','data_query_id', 'data_query_type','data_answers_0', 'data_answers_1', 'data_answers_2', 'data_answers_3', 'data_passages_0_passage_text','data_passages_1_passage_text', 'data_passages_2_passage_text', 'data_passages_3_passage_text','data_passages_4_passage_text','data_passages_5_passage_text', 'data_passages_6_passage_text', 'data_passages_7_passage_text', 'data_passages_8_passage_text', 'data_passages_9_passage_text','data_passages_10_passage_text','data_passages_11_passage_text','num_passages','num_answers' ]
df_final.to_csv('DATASET1.csv',index=False)

# %% [markdown]
# # Creating Dataset 2
# For all questions with a single passage marked and multiple answers, consider only one answer - the answer with the highest Rouge-L match with the single passage.

# %%
import sys
stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('utf-8')
sys.stdout = stdout
                
from rouge import Rouge 
rouge=Rouge()
import pandas as pd
import numpy as np

df_final=pd.read_csv('DATASET1.csv')
master_df=pd.DataFrame()

tot_len=len(df_final)
for kl in xrange(tot_len):
    
    
    if kl%1000==0:
        print kl
        
    if df_final.iloc[kl].num_passages==1 and df_final.iloc[kl].num_answers>1:
        
        ##Find the single passage and store it in reference 
        if isinstance(df_final.iloc[kl].data_passages_0_passage_text, str):
            passage=df_final.iloc[kl].data_passages_0_passage_text
        if isinstance(df_final.iloc[kl].data_passages_1_passage_text, str):
            passage=df_final.iloc[kl].data_passages_1_passage_text
        if isinstance(df_final.iloc[kl].data_passages_2_passage_text, str):
            passage=df_final.iloc[kl].data_passages_2_passage_text
        if isinstance(df_final.iloc[kl].data_passages_3_passage_text, str):
            passage=df_final.iloc[kl].data_passages_3_passage_text
        if isinstance(df_final.iloc[kl].data_passages_4_passage_text, str):
            passage=df_final.iloc[kl].data_passages_4_passage_text
        if isinstance(df_final.iloc[kl].data_passages_5_passage_text, str):
            passage=df_final.iloc[kl].data_passages_5_passage_text
        if isinstance(df_final.iloc[kl].data_passages_6_passage_text, str):
            passage=df_final.iloc[kl].data_passages_6_passage_text
        if isinstance(df_final.iloc[kl].data_passages_7_passage_text, str):
            passage=df_final.iloc[kl].data_passages_7_passage_text
        if isinstance(df_final.iloc[kl].data_passages_8_passage_text, str):
            passage=df_final.iloc[kl].data_passages_8_passage_text
        if isinstance(df_final.iloc[kl].data_passages_9_passage_text, str):
            passage=df_final.iloc[kl].data_passages_9_passage_text
        if isinstance(df_final.iloc[kl].data_passages_10_passage_text, str):
            passage=df_final.iloc[kl].data_passages_10_passage_text
        if isinstance(df_final.iloc[kl].data_passages_11_passage_text, str):
            passage=df_final.iloc[kl].data_passages_11_passage_text
                     
        reference=passage
       
    
        #Find the multiple answers and store it 
        list_answers=[]
        for ans_ind in xrange(df_final.iloc[kl].num_answers):
            req_ind=ans_ind+3
            list_answers.append(df_final.iloc[kl][req_ind])
            
        
        only_answer=""
        present_rouge_l_f=0.0

        
        for ind in xrange(df_final.iloc[kl].num_answers):      
          
            hypothesis=list_answers[ind]
            scores = rouge.get_scores(reference, hypothesis)
            dict_scores=scores[0]
            
            if dict_scores['rouge-l']['f']>=present_rouge_l_f:
                only_answer=list_answers[ind]
                present_rouge_l_f=dict_scores['rouge-l']['f']
            
        df_now=pd.DataFrame()
        df_now=df_final.iloc[kl]
        df_now['data_answers_0']=only_answer
        df_now['data_answers_1']=np.nan
        df_now['data_answers_2']=np.nan
        df_now['data_answers_3']=np.nan
        df_now['num_answers']=1
        master_df=master_df.append(df_now)
        
    else:
        df_now=pd.DataFrame()
        df_now=df_final.iloc[kl]
        master_df=master_df.append(df_now)
        
        
df_final_new=pd.DataFrame()
df_final_new=master_df
df_final_new.to_csv('DATASET2.csv',index=False)

# %% [markdown]
# # Creating Dataset 3
# For questions with more than one answer, and more than one paragraph marked - split it into n differnet data points such that n=number of answers, and for every answer, consider just the paragraph with the max rouge L match.

# %%
import sys
stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('utf-8')
sys.stdout = stdout

from rouge import Rouge 
rouge=Rouge()
import pandas as pd
import numpy as np
df_final=pd.DataFrame()

df_final=pd.read_csv('DATASET2.csv')
len_3=len(df_final)

master_df_3=pd.DataFrame()

for index in xrange(len_3):
    if index%1000==0:
        print index
        
    passage_list=[]
    if isinstance(df_final.iloc[index].data_passages_0_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_0_passage_text)
    if isinstance(df_final.iloc[index].data_passages_1_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_1_passage_text) 
    if isinstance(df_final.iloc[index].data_passages_2_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_2_passage_text)
    if isinstance(df_final.iloc[index].data_passages_3_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_3_passage_text) 
    if isinstance(df_final.iloc[index].data_passages_4_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_4_passage_text)
    if isinstance(df_final.iloc[index].data_passages_5_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_5_passage_text)
    if isinstance(df_final.iloc[index].data_passages_6_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_6_passage_text)
    if isinstance(df_final.iloc[index].data_passages_7_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_7_passage_text)
    if isinstance(df_final.iloc[index].data_passages_8_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_8_passage_text)   
    if isinstance(df_final.iloc[index].data_passages_9_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_9_passage_text)
    if isinstance(df_final.iloc[index].data_passages_10_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_10_passage_text)
    if isinstance(df_final.iloc[index].data_passages_11_passage_text, str):
        passage_list.append(df_final.iloc[index].data_passages_11_passage_text)

    answers_list=[]
    if isinstance(df_final.iloc[index].data_answers_0, str):
        answers_list.append(df_final.iloc[index].data_answers_0)        
    if isinstance(df_final.iloc[index].data_answers_1, str):
        answers_list.append(df_final.iloc[index].data_answers_1)        
    if isinstance(df_final.iloc[index].data_answers_2, str):
        answers_list.append(df_final.iloc[index].data_answers_2)       
    if isinstance(df_final.iloc[index].data_answers_3, str):
        answers_list.append(df_final.iloc[index].data_answers_3)

    if df_final.iloc[index].num_answers>1:
        
        for index_a in xrange(len(answers_list)):     
            only_answer=answers_list[index_a]
            hypothesis=answers_list[index_a]
        
            present_rouge_l_f=0.0
            only_passage=""
            actual_index=0
            only_passage_a=""
            only_passage_b=""
            
            for index_p in xrange(len(passage_list)):
            
                reference=passage_list[index_p]
                scores = rouge.get_scores(reference, hypothesis)
                dict_scores=scores[0]

                if dict_scores['rouge-l']['f']>=present_rouge_l_f:
                    only_passage=passage_list[index_p]
                    actual_index=index_p
                    present_rouge_l_f=dict_scores['rouge-l']['f']
                    
                
            #for index_new_a in xrange(len(passage_list)):
            #    if index_new_a!=actual_index:
            #        only_passage_a=passage_list[index_new_a]
            #        actual_index_a=index_new_a
            
            
            #for index_new_b in xrange(len(passage_list)):
            #    if index_new_b!=actual_index and index_new_b!=actual_index_a:
            #        only_passage_b=passage_list[index_new_b]
            #        actual_index_b=index_new_b
                    
                    
            
                
            df_now=pd.DataFrame()
        
            df_now=df_final.iloc[index]
            df_now['data_answers_0']=only_answer
            df_now['data_answers_1']=np.nan
            df_now['data_answers_2']=np.nan
            df_now['data_answers_3']=np.nan
            df_now['num_answers']=1
                
                
            df_now['data_passages_0_passage_text']=only_passage
            #df_now['data_passages_1_passage_text']=only_passage_a
            #df_now['data_passages_2_passage_text']=only_passage_b
            df_now['data_passages_1_passage_text']=np.nan
            df_now['data_passages_2_passage_text']=np.nan
            df_now['data_passages_3_passage_text']=np.nan
            df_now['data_passages_4_passage_text']=np.nan
            df_now['data_passages_5_passage_text']=np.nan
            df_now['data_passages_6_passage_text']=np.nan
            df_now['data_passages_7_passage_text']=np.nan
            df_now['data_passages_8_passage_text']=np.nan
            df_now['data_passages_9_passage_text']=np.nan
            df_now['data_passages_10_passage_text']=np.nan
            df_now['data_passages_11_passage_text']=np.nan

            df_now['num_passages']=1
    
            master_df_3=master_df_3.append(df_now) 
         
    else:
        df_now=pd.DataFrame()
        df_now=df_final.iloc[index]
        master_df_3=master_df_3.append(df_now)
        
       
df_final_new_3=pd.DataFrame()
df_final_new_3=master_df_3
df_final_new_3.to_csv('DATASET3.csv',index=False)
        
print len(df_final_3)
print len(df_final_new_3)

# %% [markdown]
# # Converting it back to json
# ** Added extra 50 lines to all 3 files, need to delete them manually **

# %%
import pandas as pd
df_final=pd.read_csv('DATASET3.csv')
len_df_final=len(df_final)
print list(df_final)
print len_df_final


import json

jsonfile_train = open('TRAIN.json', 'w')
jsonfile_test = open('TEST.json', 'w')
jsonfile_eval=open('EVAL.json', 'w')
#jsonfile=open('DATASET3.json', 'w')

for index in xrange(len_df_final):#len_df1
    if index%1000==0:
        print index
   
    
    passages_list=[]
    
    if isinstance(df_final.iloc[index].data_passages_0_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_0_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_1_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_1_passage_text
        passages_list.append(passage_now)
        
        
    if isinstance(df_final.iloc[index].data_passages_2_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_2_passage_text
        passages_list.append(passage_now)
        
        
    if isinstance(df_final.iloc[index].data_passages_3_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_3_passage_text
        passages_list.append(passage_now)
        
        
    if isinstance(df_final.iloc[index].data_passages_4_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_4_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_5_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_5_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_6_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_6_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_7_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_7_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_8_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_8_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_9_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_9_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_10_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_10_passage_text
        passages_list.append(passage_now)
        
    if isinstance(df_final.iloc[index].data_passages_11_passage_text, str):
        passage_now=df_final.iloc[index].data_passages_11_passage_text
        passages_list.append(passage_now)

      

    val="1.0"
    json_passages_list=[]

    for ind in xrange(len(passages_list)):
        #print "\nPassage "+str(ind+1)+":   "+str(passages_list[ind])
        
        json_data_passages = dict()
        
        json_data_passages["is_selected"] = val
        json_data_passages["url"]="not_req"
        json_data_passages["passage_text"]=passages_list[ind]
        
        #print "\n"
        #print json_data_passages
        
        json_passages_list.append(json_data_passages)
  
    json_row= dict()
    json_row["passages"]=json_passages_list
    json_row["query_id"]=df_final.iloc[index].data_query_id
    json_row["query_type"]=df_final.iloc[index].data_query_type
    json_row["query"]=df_final.iloc[index].data_query_codemixed
    json_row["answers"]=[df_final.iloc[index].data_answers_0]
    
    #print json_row
    
    if index%10<8: 
        json.dump(json_row, jsonfile_train)
        jsonfile_train.write('\n')
    
    elif index%10==9: 
        json.dump(json_row, jsonfile_test)
        jsonfile_test.write('\n')
        
    elif index%10==8:
        json.dump(json_row, jsonfile_eval)
        jsonfile_eval.write('\n')
     

json_row=json_row

num=0
while num<50:
    num+=1
    json.dump(json_row, jsonfile_train)
    jsonfile_train.write('\n')
    
num=0
while num<50:
    num+=1
    json.dump(json_row, jsonfile_test)
    jsonfile_test.write('\n')
    
num=0
while num<50:
    num+=1
    json.dump(json_row, jsonfile_eval)
    jsonfile_eval.write('\n')

    
## Added extra 50 lines to all 3 files, delete them manually 

count_full=0
count=0
import json
for line in open('TRAIN.json', 'r'):
    #line_new=json.loads(line)
    count+=1
print count
count_full+=count


count=0
import json
for line in open('EVAL.json', 'r'):
    #line_new=json.loads(line)
    count+=1
print count
count_full+=count


count=0
import json
for line in open('TEST.json', 'r'):
    #line_new=json.loads(line)
    count+=1
print count
count_full+=count

print count_full
print len_df_final
